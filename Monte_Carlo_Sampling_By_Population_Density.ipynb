# %%
include("functions/retrieve_nsrdb_data.jl");

# %%
pv_output = monte_carlo_solar_output(num_samples=2)
# Out:
#  0.00 %  @ 0
#  0.67 %  @ 175
#  1.34 %  @ 350
#  2.00 %  @ 525
#  2.67 %  @ 700
#  3.33 %  @ 875
#  4.00 %  @ 1050
#  4.67 %  @ 1225
#  5.33 %  @ 1400
#  6.00 %  @ 1575
#  6.66 %  @ 1750
#  7.33 %  @ 1925
#  7.99 %  @ 2100
#  8.66 %  @ 2275
#  9.33 %  @ 2450
#  9.99 %  @ 2625
# 10.66 %  @ 2800
# 11.32 %  @ 2975
# 11.99 %  @ 3150
# 12.66 %  @ 3325
# 13.32 %  @ 3500
# 13.99 %  @ 3675
# 14.65 %  @ 3850
# 15.32 %  @ 4025
# 15.99 %  @ 4200
# 16.65 %  @ 4375
# 17.32 %  @ 4550
# 17.98 %  @ 4725
# 18.65 %  @ 4900
# 19.32 %  @ 5075
# 19.98 %  @ 5250
# 20.65 %  @ 5425
# 21.31 %  @ 5600
# 21.98 %  @ 5775
# 22.64 %  @ 5950
# 23.31 %  @ 6125
# 23.98 %  @ 6300
# 24.64 %  @ 6475
# 25.31 %  @ 6650
# 25.97 %  @ 6825
# 26.64 %  @ 7000
# 27.31 %  @ 7175
# 27.97 %  @ 7350
# 28.64 %  @ 7525
# 29.30 %  @ 7700
# 29.97 %  @ 7875
# 30.64 %  @ 8050
# 31.30 %  @ 8225
# 31.97 %  @ 8400
# 32.63 %  @ 8575
# 33.30 %  @ 8750
#  0.00 %  @ 0
#  0.67 %  @ 175
#  1.34 %  @ 350
#  2.00 %  @ 525
#  2.67 %  @ 700
# ...
